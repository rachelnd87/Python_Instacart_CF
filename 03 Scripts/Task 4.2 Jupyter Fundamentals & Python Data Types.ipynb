# %% [markdown]
# ## Contents
#     01.Importing libraries
#     02.Working with Python Data Types

# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Working with Python Data Types

# %%
# 01 Result 100
x=90+10

# %%
x
# Out:
# 100

# %%
# 02 Result 100
y=50+50

# %%
y
# Out:
# 100

# %%
# 03 Result 100
z=125-25

# %%
z
# Out:
# 100

# %%
#01 Floating-Point Variable
q=12.2

# %%
#02 Floating-Point Variable
w=2.4

# %%
q/w
# Out:
# 5.083333333333333

# %%
#Strings Word
a='Car'
b='eer'
c='Foun'
d='dry'

# %%
a+b+c+d
# Out:
# 'CareerFoundry'

# %%
#01 Strings Sentence
e='Hi, '
f='my name '
g='is Rachel.'

# %%
e+f+g
# Out:
# 'Hi, my name is Rachel.'

# %%
#02 Strings Sentence
h='I loved '
i='this part: '
j='potato'

# %%
h+i+(j*12)
# Out:
# 'I loved this part: potatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotato'

# %%
#Bonus Task--lets make it better!
j*100
# Out:
# '...'
