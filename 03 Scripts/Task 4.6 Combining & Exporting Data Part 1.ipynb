# %% [markdown]
# ## Contents
#     01.Importing libraries
#     02.Importing Data
#     03.Merging Tables

# %% [markdown]
# # 01.Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02.Importing Data

# %%
path=r'C:\Users\rache\Documents\Instacart Basket Analysis'

# %%
# Importing order_products_prior.csv
df_ords_prior=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'))

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Importing orders_cleaned.csv
df_ords=pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_cleaned.csv'))

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# # 03.Merging Tables

# %%
# Merging df_ords_prior & df_ords using order_id column
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           0   2539329        1             1                  2
# 2           0   2539329        1             1                  2
# 3           0   2539329        1             1                  2
# 4           0   2539329        1             1                  2
#
#    order_hour_of_day  days_since_last_order  first_time_customer  product_id  \
# 0                  8                    NaN                 True         196
# 1                  8                    NaN                 True       14084
# 2                  8                    NaN                 True       12427
# 3                  8                    NaN                 True       26088
# 4                  8                    NaN                 True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Checking merge frequency
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Removing unnamed column
df_merged_large = df_merged_large.drop(columns = ['Unnamed: 0'])

# %%
# Exporting data to pkl
df_merged_large.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  first_time_customer  product_id  add_to_cart_order  \
# 0                    NaN                 True         196                  1
# 1                    NaN                 True       14084                  2
# 2                    NaN                 True       12427                  3
# 3                    NaN                 True       26088                  4
# 4                    NaN                 True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...
